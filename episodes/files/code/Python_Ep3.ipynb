# %% [markdown]
# <a href="https://colab.research.google.com/github/broadinstitute/2024-06-24-python-novice-lesson/blob/jlc_final_edits/episodes/files/code/Python_Ep3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Intro to Python Epsiode 3

# %%
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/swc-python/data/'
# Out:
# Mounted at /content/drive

# %%
import numpy
data = numpy.loadtxt(fname=file_path + 'inflammation-01.csv', delimiter=',')

# %%
import matplotlib.pyplot
image = matplotlib.pyplot.imshow(data)
matplotlib.pyplot.show()

# %% [markdown]
# Instead of typing `matplotlib.pyplot` on every line, you can tell Python to use a shortcut of your choosing, we'll use `plt` in this example. Just make sure the shortcut is distinct from any Python library you might want to use.

# %%
import matplotlib.pyplot as plt
image = plt.imshow(data)
plt.ylabel('Patients')
plt.xlabel('Day')
plt.show()

# %%
import matplotlib.pyplot
ave_inflammation = numpy.mean(data, axis=0)
ave_plot = matplotlib.pyplot.plot(ave_inflammation)
matplotlib.pyplot.show()

# %%
max_plot = matplotlib.pyplot.plot(numpy.amax(data, axis=0))
matplotlib.pyplot.show()

# %%
min_plot = matplotlib.pyplot.plot(numpy.amin(data, axis=0))
matplotlib.pyplot.show()

# %%
import numpy
import matplotlib.pyplot

data = numpy.loadtxt(fname=file_path + 'inflammation-01.csv', delimiter=',')

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

axes1.set_ylabel('average')
axes1.plot(numpy.mean(data, axis=0))

axes2.set_ylabel('max')
axes2.plot(numpy.amax(data, axis=0))

axes3.set_ylabel('min')
axes3.plot(numpy.amin(data, axis=0))

matplotlib.pyplot.savefig('inflammation.png')
matplotlib.pyplot.show()

# %%
import numpy
import matplotlib.pyplot

data = numpy.loadtxt(fname=file_path + 'inflammation-01.csv', delimiter=',')

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

axes1.set_ylabel('average')
mean_data = numpy.mean(data, axis=0)
axes1.plot(mean_data)
axes1.set_ylim(numpy.amin(mean_data), numpy.amax(mean_data) * 1.1)

axes2.set_ylabel('max')
max_data = numpy.amax(data, axis=0)
axes2.plot(max_data)
axes2.set_ylim(numpy.amin(max_data), numpy.amax(max_data) * 1.1)

axes3.set_ylabel('min')
min_data = numpy.amin(data, axis=0)
axes3.plot(min_data)
axes3.set_ylim(numpy.amin(min_data), numpy.amax(min_data) * 1.1)

matplotlib.pyplot.savefig('inflammation.png')
matplotlib.pyplot.show()

# %%
import numpy
import matplotlib.pyplot

data = numpy.loadtxt(fname=file_path + 'inflammation-01.csv', delimiter=',')

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

axes1.set_ylabel('average')
axes1.plot(numpy.mean(data, axis=0), drawstyle='steps-mid')

axes2.set_ylabel('max')
axes2.plot(numpy.amax(data, axis=0), drawstyle='steps-mid')

axes3.set_ylabel('min')
axes3.plot(numpy.amin(data, axis=0), drawstyle='steps-mid')

fig.tight_layout()

matplotlib.pyplot.show()

# %%
std_plot = matplotlib.pyplot.plot(numpy.std(data, axis=0))
matplotlib.pyplot.show()
